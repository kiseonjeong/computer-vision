# %% [markdown]
# <a href="https://colab.research.google.com/github/kiseonjeong/computer-vision/blob/2-study-the-super-resolution-algorithm/super%20resolution/cifar10_srresnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
def normalize(x):
    return x / 255.0

def denormalize(x):
    return (x + 1) * 127.5

def pixel_shuffle(scale):
    return lambda x: tf.nn.depth_to_space(x, scale)

# %%
# Set input layer
inputs = keras.Input(shape=(32, 32, 3), name='img')
x = layers.Lambda(normalize)(inputs)

x = layers.Conv2D(filters=64, kernel_size=9, padding='same')(x)
x = x_1 = layers.PReLU(shared_axes=[1, 2])(x)

# Set 1st res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 2nd res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 3rd res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 4th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 5th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 6th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 7th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 8th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 9th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 10th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 11th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 12th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 13th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 14th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 15th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

# Set 16th res. block layer
x = x_in = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.PReLU(shared_axes=[1, 2])(x)
x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_in, x])

x = layers.Conv2D(filters=64, kernel_size=3, padding='same')(x)
x = layers.BatchNormalization(momentum=0.8)(x)
x = layers.Add()([x_1, x])

# Set 1st up sampling layer (64x64)
x = layers.Conv2D(filters=64 * 4, kernel_size=3, padding='same')(x)
x = layers.Lambda(pixel_shuffle(2))(x)
x = layers.PReLU(shared_axes=[1, 2])(x)

# Set 2nd up sampling layer (128x128)
x = layers.Conv2D(filters=64 * 4, kernel_size=3, padding='same')(x)
x = layers.Lambda(pixel_shuffle(2))(x)
x = layers.PReLU(shared_axes=[1, 2])(x)

# Set output layer
x = layers.Conv2D(filters=3, kernel_size=9, padding='same', activation='tanh')(x)
outputs = layers.Lambda(denormalize)(x)

# Set a SR-ResNet model
model = keras.Model(inputs, outputs, name='SR-ResNet')
model.summary()
# Out:
# Model: "SR-ResNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  img (InputLayer)               [(None, 32, 32, 3)]  0           []
#
#  lambda (Lambda)                (None, 32, 32, 3)    0           ['img[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   15616       ['lambda[0][0]']
#
#  p_re_lu (PReLU)                (None, 32, 32, 64)   64          ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 64)   36928       ['p_re_lu[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d_1[0][0]']
#  alization)
#
#  p_re_lu_1 (PReLU)              (None, 32, 32, 64)   64          ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   36928       ['p_re_lu_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_2[0][0]']
# ...

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load image data
ishape = 128
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# Reduce the dataset
train_image = train_images[0:10000]
test_image = test_images[0:1000]

x_train = np.array([img for img in train_image])
x_test = np.array([img for img in test_image])

y_train = np.array([cv.resize(img, (ishape, ishape), interpolation=cv.INTER_CUBIC) for img in train_image])
y_test = np.array([cv.resize(img, (ishape, ishape), interpolation=cv.INTER_CUBIC) for img in test_image])

# Show an example image
example_idx = 123
plt.figure('LR')
plt.imshow(x_train[example_idx])
plt.title('low resolution image')
plt.figure('HR')
plt.imshow(y_train[example_idx])
plt.title('high resolution image')
plt.show()

# %%
# Train the model
def PSNR(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=255.0)

def SSIM(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=255.0)

model.compile(optimizer=keras.optimizers.Adam(0.0001), loss='mse', metrics=[PSNR, SSIM, 'accuracy'])

history = model.fit(x_train, y_train, batch_size=64, epochs=10, validation_split=0.2)

test_scores = model.evaluate(x_test, y_test, verbose=2)

print('Test loss:', test_scores[0])
print('Test mse:', test_scores[1])

# Save entire model to a HDF5 file
model.save('SR-ResNet.h5')
# Out:
# Epoch 1/10
# 125/125 [==============================] - 128s 867ms/step - loss: 858.6051 - PSNR: 20.2208 - SSIM: 0.5129 - accuracy: 0.5172 - val_loss: 337.6797 - val_PSNR: 23.2776 - val_SSIM: 0.6620 - val_accuracy: 0.6151
# Epoch 2/10
# 125/125 [==============================] - 107s 853ms/step - loss: 286.4049 - PSNR: 24.0374 - SSIM: 0.7155 - accuracy: 0.6495 - val_loss: 192.3481 - val_PSNR: 25.7209 - val_SSIM: 0.7584 - val_accuracy: 0.6963
# Epoch 3/10
# 125/125 [==============================] - 106s 850ms/step - loss: 202.8818 - PSNR: 25.4761 - SSIM: 0.7788 - accuracy: 0.7156 - val_loss: 146.3000 - val_PSNR: 26.8942 - val_SSIM: 0.8052 - val_accuracy: 0.7270
# Epoch 4/10
# 125/125 [==============================] - 106s 850ms/step - loss: 160.7730 - PSNR: 26.4906 - SSIM: 0.8150 - accuracy: 0.7447 - val_loss: 123.3295 - val_PSNR: 27.6173 - val_SSIM: 0.8293 - val_accuracy: 0.7641
# Epoch 5/10
# ...

# %%
# Set real test image
img = train_images[20001]
lr = np.array(img)
hr = np.array(cv.resize(img, (ishape, ishape), interpolation=cv.INTER_CUBIC))
test_input = np.reshape(lr, (1, 32, 32, 3))

# Predict a result
sr = model.predict(test_input)
plt.figure('LR')
plt.title('low resolution image')
plt.imshow(lr)
plt.figure('HR')
plt.title('high resolution image')
plt.imshow(hr)
plt.figure('SR')
plt.title('super resolution image')
plt.imshow(sr[0] / 255.0)
plt.show()
